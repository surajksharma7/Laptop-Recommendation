# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data = pd.read_csv('data/Dataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   brand                                  name  price  \
# 0           0      HP      Victus 15-fb0157AX Gaming Laptop  49900
# 1           1      HP                   15s-fq5007TU Laptop  39900
# 2           2    Acer                  One 14 Z8-415 Laptop  26990
# 3           3  Lenovo  Yoga Slim 6 14IAP8 82WU0095IN Laptop  59729
# 4           4   Apple       MacBook Air 2020 MGND3HN Laptop  69990
#
#    spec_rating                      processor                             CPU  \
# 0    73.000000      5th Gen AMD Ryzen 5 5600H           Hexa Core, 12 Threads
# 1    60.000000   12th Gen Intel Core i3 1215U  Hexa Core (2P + 4E), 8 Threads
# 2    69.323529  11th Gen Intel Core i3 1115G4            Dual Core, 4 Threads
# 3    66.000000   12th Gen Intel Core i5 1240P  12 Cores (4P + 8E), 16 Threads
# 4    69.323529                       Apple M1             Octa Core (4P + 4E)
#
#     Ram Ram_type    ROM ROM_type                           GPU  display_size  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0 brand                                               name  \
# 888         888  Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889         889  Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890         890  Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891         891  Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892         892  Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#       price  spec_rating                      processor  \
# 888   44990    69.323529  13th Gen ‎Intel Core i3 1315U
# 889  110000    71.000000      6th Gen AMD Ryzen 7 6800H
# 890  189990    89.000000     7th Gen AMD Ryzen 9 7940HS
# 891  129990    73.000000  13th Gen Intel Core i7 13700H
# 892  131990    84.000000     7th Gen AMD Ryzen 9 7940HS
#
#                                 CPU   Ram Ram_type    ROM ROM_type  \
# 888  Hexa Core (2P + 4E), 8 Threads   8GB     DDR4  512GB      SSD
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# brand                0
# name                 0
# price                0
# spec_rating          0
# processor            0
# CPU                  0
# Ram                  0
# Ram_type             0
# ROM                  0
# ROM_type             0
# GPU                  0
# display_size         0
# resolution_width     0
# resolution_height    0
# OS                   0
# warranty             0
# image                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '32GB', '2GB', '12GB', '64GB'], dtype=object)

# %%
data['ROM'].unique()
# Out:
# array(['512GB', '256GB', '128GB', '64GB', '1TB', '32GB', '2TB'],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         893 non-null    int64
#  1   brand              893 non-null    object
#  2   name               893 non-null    object
#  3   price              893 non-null    int64
#  4   spec_rating        893 non-null    float64
#  5   processor          893 non-null    object
#  6   CPU                893 non-null    object
#  7   Ram                893 non-null    object
#  8   Ram_type           893 non-null    object
#  9   ROM                893 non-null    object
#  10  ROM_type           893 non-null    object
#  11  GPU                893 non-null    object
#  12  display_size       893 non-null    float64
#  13  resolution_width   893 non-null    int64
#  14  resolution_height  893 non-null    int64
#  15  OS                 893 non-null    object
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0          price  spec_rating  display_size  resolution_width  \
# count  893.000000     893.000000   893.000000    893.000000        893.000000
# mean   446.000000   79907.409854    69.379026     15.173751       2035.393057
# std    257.931192   60880.043823     5.541555      0.939095        426.076009
# min      0.000000    9999.000000    60.000000     11.600000       1080.000000
# 25%    223.000000   44500.000000    66.000000     14.000000       1920.000000
# 50%    446.000000   61990.000000    69.323529     15.600000       1920.000000
# 75%    669.000000   90990.000000    71.000000     15.600000       1920.000000
# max    892.000000  450039.000000    89.000000     18.000000       3840.000000
#
#        resolution_height    warranty
# count         893.000000  893.000000
# mean         1218.324748    1.079507
# std           326.756883    0.326956
# min           768.000000    0.000000
# 25%          1080.000000    1.000000
# 50%          1080.000000    1.000000
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['price'], kde=True, color='blue', bins=20)
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.title('Histogram of Laptop Prices')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='brand', data=data, order=data['brand'].value_counts().index)
plt.xlabel('Count')
plt.ylabel('Brand')
plt.title('Bar Chart of Laptop Brands')
plt.show()

# %%
sns.countplot(y='processor', data=data, order=data['processor'].value_counts().index, palette='muted')
plt.xlabel('Count')
plt.ylabel('Processor')
plt.title('Bar Chart of Laptop Processors')
plt.show()

# %%
sns.countplot(y='Ram', data=data, order=data['Ram'].value_counts().index, palette='muted')
plt.xlabel('Count')
plt.ylabel('RAM')
plt.title('Bar Chart of Laptop RAM Sizes')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='ROM', data=data, order=data['ROM'].value_counts().index, palette='muted')
plt.xlabel('Count')
plt.ylabel('Storage')
plt.title('Bar Chart of Laptop Storage Types')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='display_size', data=data, order=data['display_size'].value_counts().index, palette='muted')
plt.xlabel('Count')
plt.ylabel('Screen Size')
plt.title('Bar Chart of Laptop Screen Sizes')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(data['price'])
plt.xlabel('Laptops')
plt.ylabel('Price (euros)')
plt.title('Boxplot of Laptop Prices')
plt.show()

# %%
data['brand'].value_counts(normalize=True)
# Out:
# HP           0.208287
# Lenovo       0.189250
# Asus         0.175812
# Dell         0.119821
# Acer         0.094065
# MSI          0.072788
# Samsung      0.031355
# Apple        0.017917
# Infinix      0.016797
# LG           0.010078
# Xiaomi       0.008959
# Gigabyte     0.008959
# Fujitsu      0.006719
# Zebronics    0.004479
# Ultimus      0.004479
# Tecno        0.003359
# Wings        0.003359
# Chuwi        0.003359
# Realme       0.003359
# Microsoft    0.002240
# AXL          0.002240
# Huawei       0.002240
# Honor        0.002240
# Walker       0.001120
# Vaio         0.001120
# Avita        0.001120
# Primebook    0.001120
# Ninkear      0.001120
# Razer        0.001120
# iBall        0.001120
# Name: brand, dtype: float64

# %%
data['brand'].value_counts()
# Out:
# HP           186
# Lenovo       169
# Asus         157
# Dell         107
# Acer          84
# MSI           65
# Samsung       28
# Apple         16
# Infinix       15
# LG             9
# Xiaomi         8
# Gigabyte       8
# Fujitsu        6
# Zebronics      4
# Ultimus        4
# Tecno          3
# Wings          3
# Chuwi          3
# Realme         3
# Microsoft      2
# AXL            2
# Huawei         2
# Honor          2
# Walker         1
# Vaio           1
# Avita          1
# Primebook      1
# Ninkear        1
# Razer          1
# iBall          1
# Name: brand, dtype: int64

# %%
mean_price = data['price'].mean()
median_price = data['price'].median()
std_dev_price = data['price'].std()


print("Descriptive statistics for numerical variable 'Price':")
print("Mean:", mean_price)
print("Median:", median_price)
print("Standard Deviation:", std_dev_price)
# Out:
# Descriptive statistics for numerical variable 'Price':
# Mean: 79907.4098544233
# Median: 61990.0
# Standard Deviation: 60880.043823052976

# %%
# Kernel Density Estimation (KDE) plot
plt.figure(figsize=(10, 6))
sns.kdeplot(data['price'], fill=True, color='orange')
plt.title('Kernel Density Estimation of Laptop Prices')
plt.xlabel('Price')
plt.ylabel('Density')
plt.show()

# %%
# Correlation matrix
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_10892\3230546549.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='display_size', y='price', data=data, color='blue')
plt.title('Scatter Plot of Price vs. Screen Size')
plt.xlabel('Screen Size (Inches)')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='brand', y='price', data=data, palette='Set3')
plt.title('Box Plot of Price by Brand')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
# Select relevant numeric columns for pair plot
numeric_cols = ['price', 'Ram', 'processor']

# Create pair plot
sns.pairplot(data[numeric_cols])
plt.title('Pair Plot of Numeric Variables')
plt.show()

# %%
columns = data.columns

# Initialize a list to store duplicate columns
duplicate_columns = []

# Iterate over all pairs of columns
for i in range(len(columns)):
    for j in range(i + 1, len(columns)):
        # Check if column i is equal to column j
        if (data[columns[i]] == data[columns[j]]).all():
            # If they are equal, add column j to the list of duplicate columns
            duplicate_columns.append(columns[j])

# Remove duplicate columns from the DataFrame
df = data.drop(columns=duplicate_columns)

# %%
df
# Out:
#      Unnamed: 0   brand                                               name  \
# 0             0      HP                   Victus 15-fb0157AX Gaming Laptop
# 1             1      HP                                15s-fq5007TU Laptop
# 2             2    Acer                               One 14 Z8-415 Laptop
# 3             3  Lenovo               Yoga Slim 6 14IAP8 82WU0095IN Laptop
# 4             4   Apple                    MacBook Air 2020 MGND3HN Laptop
# ..          ...     ...                                                ...
# 888         888    Asus          Vivobook 15X 2023 K3504VAB-NJ321WS Laptop
# 889         889    Asus                     TUF A15 FA577RM-HQ032WS Laptop
# 890         890    Asus  ROG Zephyrus G14 2023 GA402XV-N2034WS Gaming L...
# 891         891    Asus  TUF Gaming F15 2023 FX507VU-LP083WS Gaming Laptop
# 892         892    Asus  TUF Gaming A15 2023 FA577XU-LP041WS Gaming Laptop
#
#       price  spec_rating                      processor  \
# ...

# %%
equal_columns = []

# Iterate over all pairs of columns
for i in range(len(df.columns)):
    for j in range(i + 1, len(df.columns)):
        # Check if the values in column i are equal to the values in column j
        if df.iloc[:, i].equals(df.iloc[:, j]):
            # If they are equal, add the pair of column indices to the list
            equal_columns.append((df.columns[i], df.columns[j]))

# Print the pairs of columns with equal values
for pair in equal_columns:
    print("Columns {} and {} have equal values.".format(pair[0], pair[1]))

# %%
equal_columns
# Out:
# []

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def preprocess_data(data):
    features = ['brand', 'processor', 'CPU', 'Ram', 'Ram_type', 'ROM', 'ROM_type', 'GPU',
                'display_size', 'resolution_width', 'resolution_height', 'OS', 'warranty']
    for feature in features:
        data[feature] = data[feature].astype(str)
    data['description'] = data[features].apply(lambda x: ' '.join(x), axis=1)
    return data

# %%
def compute_similarity_matrix(data):
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf_vectorizer.fit_transform(data['description'])
    similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
    return similarity_matrix

# %%
def recommend_laptops(selected_laptop, similarity_matrix, data):
    # Preprocess selected laptop's specs
    selected_laptop = ' '.join(selected_laptop.values())

    # Compute similarity scores
    tfidf_vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf_vectorizer.fit_transform([selected_laptop] + list(data['description']))
    similarity_scores = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])[0]

    # Get indices of similar laptops
    similar_laptops_indices = similarity_scores.argsort()[::-1][1:4]  # Top 3 similar laptops

    # Get similar laptops data
    similar_laptops_data = data.iloc[similar_laptops_indices]

    return similar_laptops_data

# %%
data = preprocess_data(data)

# %%
similarity_matrix = compute_similarity_matrix(data)

# %%
recommended_laptops = recommend_laptops(selected_laptop, similarity_matrix, data)
recommended_laptops
# Out:
#      Unnamed: 0 brand                              name  price  spec_rating  \
# 597         597    HP  Victus 15-fb0158AX Gaming Laptop  49990         67.0
# 190         190    HP  Victus 15-fb0777AX Gaming Laptop  51990         67.0
# 134         134    HP  Victus 15-fb0108AX Gaming Laptop  51499         67.0
#
#                        processor                    CPU  Ram Ram_type    ROM  \
# 597  5th Gen AMD Ryzen 5  5600H   Hexa Core, 12 Threads  8GB     DDR4  512GB
# 190  5th Gen AMD Ryzen 5  5600H   Hexa Core, 12 Threads  8GB     DDR4  512GB
# 134  5th Gen AMD Ryzen 5  5600H   Hexa Core, 12 Threads  8GB     DDR4  512GB
#
#     ROM_type                               GPU display_size resolution_width  \
# 597      SSD           4GB AMD Radeon RX 6500M         15.6             1920
# 190      SSD  4GB AMD Radeon RX 6500M Graphics         15.6             1920
# 134      SSD  4GB AMD Radeon RX 6500M Graphics         15.6             1920
#
# ...

# %%
# Save DataFrame as pickle file
data.to_pickle('laptop_data.pkl')
